# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"covid.csv")

# %%
data
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 0          0  2020-02-24T18:00:00     ITA          13    Abruzzo
# 1          1  2020-02-24T18:00:00     ITA          13    Abruzzo
# 2          2  2020-02-24T18:00:00     ITA          13    Abruzzo
# 3          3  2020-02-24T18:00:00     ITA          13    Abruzzo
# 4          4  2020-02-24T18:00:00     ITA          13    Abruzzo
# ...      ...                  ...     ...         ...        ...
# 40196  40196  2020-12-06T17:00:00     ITA           5     Veneto
# 40197  40197  2020-12-06T17:00:00     ITA           5     Veneto
# 40198  40198  2020-12-06T17:00:00     ITA           5     Veneto
# 40199  40199  2020-12-06T17:00:00     ITA           5     Veneto
# 40200  40200  2020-12-06T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                          ProvinceName  \
# 0                66                              L'Aquila
# 1                67                                Teramo
# ...

# %%
data.head()
# Out:
#    SNo                 Date Country  RegionCode RegionName  ProvinceCode  \
# 0    0  2020-02-24T18:00:00     ITA          13    Abruzzo            66
# 1    1  2020-02-24T18:00:00     ITA          13    Abruzzo            67
# 2    2  2020-02-24T18:00:00     ITA          13    Abruzzo            68
# 3    3  2020-02-24T18:00:00     ITA          13    Abruzzo            69
# 4    4  2020-02-24T18:00:00     ITA          13    Abruzzo           979
#
#                            ProvinceName ProvinceAbbreviation   Latitude  \
# 0                              L'Aquila                   AQ  42.351222
# 1                                Teramo                   TE  42.658918
# 2                               Pescara                   PE  42.464584
# 3                                Chieti                   CH  42.351032
# 4  In fase di definizione/aggiornamento                  NaN        NaN
#
#    Longitude  TotalPositiveCases
# 0  13.398438                   0
# ...

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'ProvinceCode',
#        'ProvinceName', 'ProvinceAbbreviation', 'Latitude', 'Longitude',
#        'TotalPositiveCases'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'ProvinceCode',
#        'ProvinceName', 'ProvinceAbbreviation', 'Latitude', 'Longitude',
#        'TotalPositiveCases'],
#       dtype='object')

# %%
data.tail()
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 40196  40196  2020-12-06T17:00:00     ITA           5     Veneto
# 40197  40197  2020-12-06T17:00:00     ITA           5     Veneto
# 40198  40198  2020-12-06T17:00:00     ITA           5     Veneto
# 40199  40199  2020-12-06T17:00:00     ITA           5     Veneto
# 40200  40200  2020-12-06T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                          ProvinceName  \
# 40196            27                               Venezia
# 40197            28                                Padova
# 40198            29                                Rovigo
# 40199           899    Fuori Regione / Provincia Autonoma
# 40200           999  In fase di definizione/aggiornamento
#
#       ProvinceAbbreviation   Latitude  Longitude  TotalPositiveCases
# 40196                   VE  45.434905  12.338452               24142
# 40197                   PD  45.406930  11.876087               31073
# ...

# %%
data.describe()
# Out:
#                 SNo    RegionCode  ProvinceCode      Latitude     Longitude  \
# count  40201.000000  40201.000000  40201.000000  30709.000000  30709.000000
# mean   20100.000000     10.357354    266.261188     42.908522     12.096599
# std    11605.173423      5.993795    383.221679      2.631552      2.660590
# min        0.000000      1.000000      1.000000     36.925092      7.320149
# 25%    10050.000000      5.000000     36.000000     40.914047      9.828190
# 50%    20100.000000      9.000000     71.000000     43.715532     12.104734
# 75%    30150.000000     16.000000    110.000000     45.185093     14.167546
# max    40200.000000     22.000000    999.000000     46.499335     18.171897
#
#        TotalPositiveCases
# count        40201.000000
# mean          2563.579961
# std           6884.484083
# min              0.000000
# 25%            103.000000
# 50%            642.000000
# 75%           2605.000000
# max         158717.000000

# %%
data.isnull().sum()
# Out:
# SNo                        0
# Date                       0
# Country                    0
# RegionCode                 0
# RegionName                 0
# ProvinceCode               0
# ProvinceName               0
# ProvinceAbbreviation    9779
# Latitude                9492
# Longitude               9492
# TotalPositiveCases         0
# dtype: int64

# %%
sns.relplot(x="RegionCode", y="ProvinceCode", data=data)

# %%
sn.replot(x='',y='',kind='Line', data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x='Longitude', y='Latitude', kind='line', data=data)

# %%
sns.catplot(x='Longitude', y='Latitude', data=data)

# %%
gb = df.groupby ('TotalPositiveCases'),agg ({'TotalPositiveCases':'Count'})
plt.pie gb ['TotalPositiveCases']
plt.show()
gb
# Out:
#   Cell In[1], line 2
#     plt.pie gb ['TotalPositiveCases']
#             ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# Sample COVID-19 data
labels = ["Active Cases", "Recovered", "Deaths"]
cases = [500000, 1200000, 30000]  # Example numbers

# Define colors
colors = ["skyblue", "lightgreen", "red"]

# Create pie chart
plt.figure(figsize=(7, 7))
plt.pie(cases, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140, wedgeprops={'edgecolor': 'black'})

# Add title
plt.title("COVID-19 Case Distribution")

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample COVID-19 data (in millions)
countries = ["USA", "India", "Brazil", "Russia", "UK"]
active_cases = [2.5, 1.8, 1.2, 0.9, 0.7]
recovered = [28.5, 30.2, 19.8, 8.5, 7.9]
deaths = [0.8, 0.4, 0.6, 0.3, 0.2]

# Define bar positions
x = np.arange(len(countries))

# Plot stacked bars
plt.figure(figsize=(8, 6))
plt.bar(x, active_cases, label="Active Cases", color="skyblue")
plt.bar(x, recovered, bottom=active_cases, label="Recovered", color="lightgreen")
plt.bar(x, deaths, bottom=np.array(active_cases) + np.array(recovered), label="Deaths", color="red")

# Labels and title
plt.xticks(x, countries)
plt.xlabel("Countries")
plt.ylabel("Number of Cases (in millions)")
plt.title("COVID-19 Case Distribution by Country")
plt.legend()

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample COVID-19 data
data = {
    "Country": ["USA", "India", "Brazil", "Russia", "UK", "France", "Italy", "Germany"],
    "Total Cases": [50000000, 45000000, 35000000, 25000000, 15000000, 18000000, 16000000, 14000000],
    "Deaths": [800000, 530000, 620000, 350000, 230000, 280000, 220000, 180000]
}

# Create DataFrame
df = pd.DataFrame(data)

# Set Seaborn style
sns.set_style("whitegrid")

# Create scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="Total Cases", y="Deaths", hue="Country", size="Total Cases", sizes=(50, 300), palette="coolwarm", edgecolor="black")

# Labels and title
plt.xlabel("Total COVID-19 Cases")
plt.ylabel("Total Deaths")
plt.title("COVID-19 Cases vs Deaths by Country")

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample COVID-19 data for Italy (Replace with real data)
dates = pd.date_range(start="2022-01-01", periods=10, freq="M")
active_cases = [500000, 450000, 400000, 350000, 300000, 250000, 200000, 150000, 100000, 50000]
recovered = [1000000, 1100000, 1200000, 1300000, 1400000, 1500000, 1600000, 1700000, 1800000, 1900000]
deaths = [140000, 145000, 150000, 155000, 160000, 165000, 170000, 175000, 180000, 185000]

# Create DataFrame
df = pd.DataFrame({"Date": dates, "Active Cases": active_cases, "Recovered": recovered, "Deaths": deaths})

# Plot area chart
plt.figure(figsize=(10, 6))
plt.stackplot(df["Date"], df["Active Cases"], df["Recovered"], df["Deaths"], labels=["Active Cases", "Recovered", "Deaths"], colors=["skyblue", "lightgreen", "red"], alpha=0.6)

# Labels and title
plt.xlabel("Date")
plt.ylabel("Number of Cases")
plt.title("Italy COVID-19 Cases Over Time")
plt.legend()

# Show plot
plt.show()
# Out:
# C:\Users\Dhanush\AppData\Local\Temp\ipykernel_10424\856597086.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(start="2022-01-01", periods=10, freq="M")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample COVID-19 data for Italy (Replace with real data)
data = {
    "Category": ["Active Cases"] * 10 + ["Recovered"] * 10 + ["Deaths"] * 10,
    "Cases": [500000, 450000, 400000, 350000, 300000, 250000, 200000, 150000, 100000, 50000] +
             [1000000, 1100000, 1200000, 1300000, 1400000, 1500000, 1600000, 1700000, 1800000, 1900000] +
             [140000, 145000, 150000, 155000, 160000, 165000, 170000, 175000, 180000, 185000]
}

# Create DataFrame
df = pd.DataFrame(data)

# Set Seaborn style
sns.set_style("whitegrid")

# Create violin plot
plt.figure(figsize=(8, 6))
sns.violinplot(x="Category", y="Cases", data=df, palette="coolwarm", inner="quartile")

# Labels and title
plt.xlabel("COVID-19 Category")
plt.ylabel("Number of Cases")
plt.title("Italy COVID-19 Cases Distribution")

# Show plot
plt.show()
# Out:
# C:\Users\Dhanush\AppData\Local\Temp\ipykernel_10424\3094220133.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Category", y="Cases", data=df, palette="coolwarm", inner="quartile")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Sample COVID-19 data for Italy (Replace with real data)
dates = pd.date_range(start="2022-01-01", periods=10, freq="M")
data = {
    "Date": dates,
    "Active Cases": [500000, 450000, 400000, 350000, 300000, 250000, 200000, 150000, 100000, 50000],
    "Recovered": [1000000, 1100000, 1200000, 1300000, 1400000, 1500000, 1600000, 1700000, 1800000, 1900000],
    "Deaths": [140000, 145000, 150000, 155000, 160000, 165000, 170000, 175000, 180000, 185000]
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute correlation matrix
corr = df.drop(columns=["Date"]).corr()

# Set Seaborn style
sns.set_style("whitegrid")

# Create heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5, fmt=".2f")

# Labels and title
plt.title("COVID-19 Correlation Heatmap - Italy")

# Show plot
plt.show()
# Out:
# C:\Users\Dhanush\AppData\Local\Temp\ipykernel_10424\1431283274.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(start="2022-01-01", periods=10, freq="M")
